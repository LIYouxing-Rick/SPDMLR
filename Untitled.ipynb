# %%
# %run compute_multi_seed_stats.py --results_dir "torch_results" --s 1,4,2,0,3
#01357/01457
# Out:
# 开始计算统计信息...
#
# 目录中共有 15 个项目
# 其中文件数量: 15
#
#
# 成功处理的文件分为 3 个参数组合
#
# 共找到 3 个参数组合
#
#
# ...
# Group                                                                                                                    N     Final Acc (Mean±Std)           Best Acc (Mean±Std)
# ...
# evaluation=inter-subject|net_lr=0.001|loss_lr=0.0005|optimizer=unknown|weight_decay=unknown|architect=TSMNet+SPDDSMBNLogEigMLR-[40,20]|n_proj=150|sampling=lecm|lp=on|logm=on|lamda=0.75|gamma=0.75|init_l1=0.75|init_l2=0.75|power=4.0 5     0.5239±0.0104 [0.5045-0.5327]  N/A
# evaluation=inter-subject|net_lr=0.001|loss_lr=0.0005|optimizer=unknown|weight_decay=unknown|architect=TSMNet+SPDDSMBNLogEigMLR-[40,20]|n_proj=150|sampling=olm|lp=on|logm=on|lamda=0.75|gamma=0.75|init_l1=0.75|init_l2=0.75|power=4.0 5     0.5057±0.0076 [0.4966-0.5141]  N/A
# ...

# %%
# %run compute_multi_seed_stats.py --results_dir "torch_results" --s 0,1,2,3,4
# Out:
# 开始计算统计信息...
#
# 错误: 结果目录不存在: /root/SPDMLR-main/torch_results
